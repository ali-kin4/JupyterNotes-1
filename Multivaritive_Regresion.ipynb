# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-kin4/JupyterNotes-1/blob/main/Multivaritive_Regresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd
import numpy as np
from google.colab import widgets
from google.colab import output
from IPython.display import clear_output

# %%
def

# %%
x = np.linspace(0, 1, 10)
y = np.linspace(0, 1, 10)
X, Y = np.meshgrid(x, y, copy=False)
Z = X**2 + Y**2 + np.random.rand(*X.shape)*0.01

X = X.flatten()
Y = Y.flatten()

A = np.array([X*0+1, X, Y, X**2, X**2*Y, X**2*Y**2, Y**2, X*Y**2, X*Y]).T
B = Z.flatten()

coeff, r, rank, s = np.linalg.lstsq(A, B)

clear_output()

# %%
X, Y = np.meshgrid(x, y, copy=False)

tb = widgets.TabBar(['3D Plot', '2D Contour'])


with tb.output_to('3D Plot'):
  fig = plt.figure(figsize=(8, 8))
  ax = fig.add_subplot(111, projection='3d')
  ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                        linewidth=1, antialiased=True)

  ax.set_xlabel('X')
  ax.set_ylabel('Y')
  ax.set_zlabel('Z')
  plt.show()


with tb.output_to('2D Contour'):
  plt.contourf(X, Y, Z, 10, cmap=cm.coolwarm)
  plt.colorbar();
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id4"></div>

# %%
def poly2D(X, Y, coeff):
  c = coeff
  Z = c[0] + X*c[1] + Y*c[2] + X**2*c[3] + X**2*Y*c[4] + X**2*Y**2*c[5] + Y**2*c[6] + X*Y**2*c[7] + X*Y*c[8]
  return Z

# %%
Z = poly2D(X, Y, coeff)

# %%
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=1, antialiased=True)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-6dc05d38e3e8> in <module>()
#       6 ax = fig.add_subplot(111, projection='3d')
#       7 ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
# ----> 8                        linewidth=1, antialiased=True)
#       9
#      10 ax.set_xlabel('X Label')
#
# /usr/local/lib/python3.7/dist-packages/mpl_toolkits/mplot3d/axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1502
#    1503         # TODO: Support masked arrays
# -> 1504         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#    1505         rows, cols = Z.shape
#    1506
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# ...

# %%
plt.contourf(X, Y, Z, 10, cmap=cm.coolwarm)
plt.colorbar();
