# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-kin4/JupyterNotes-1/blob/main/Multivaritive_Regresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd
import numpy as np
from google.colab import widgets
from google.colab import output
from IPython.display import clear_output

# %%
x = np.linspace(0, 1, 10)
y = np.linspace(0, 1, 10)
X, Y = np.meshgrid(x, y, copy=False)
Z = X**2 + Y**2 + np.random.rand(*X.shape)*0.01

# %%
def poly2DCalc(X, Y, Z):
  X = X.flatten()
  Y = Y.flatten()
  A = np.array([X*0+1, X, Y, X**2, X**2*Y, X**2*Y**2, Y**2, X*Y**2, X*Y]).T
  B = Z.flatten()
  coeff, r, rank, s = np.linalg.lstsq(A, B)
  clear_output()
  return coeff

# %%
def poly2D(X, Y, coeff):
  c = coeff
  Z_new = c[0] + X*c[1] + Y*c[2] + X**2*c[3] + X**2*Y*c[4] + X**2*Y**2*c[5] + Y**2*c[6] + X*Y**2*c[7] + X*Y*c[8]
  return Z_new

# %%
def plotter(X, Y, Z):
  tb = widgets.TabBar(['3D Plot', '2D Contour'])

  with tb.output_to('3D Plot'):
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                          linewidth=1, antialiased=True)

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    plt.show()


  with tb.output_to('2D Contour'):
    plt.figure(figsize=(10, 8))
    plt.contourf(X, Y, Z, 15, cmap=cm.coolwarm)
    plt.colorbar();

# %%
plotter(X, Y, Z)
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id19"></div>

# %%
coeff = poly2DCalc(X, Y, Z)

x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)

X_new, Y_new = np.meshgrid(x, y)
Z_new = poly2D(X_new, Y_new, coeff)

# %%
plotter(X_new, Y_new, Z_new)
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id20"></div>
