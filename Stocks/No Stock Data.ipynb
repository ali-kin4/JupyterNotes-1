# %%
import io
import pandas as pd
import urllib.request
import requests

# %%
url = "https://www.tgju.org/profile/geram18/history"
# r = requests.get(url, allow_redirects=True).content
calls_df = pd.read_html(url, encoding = 'utf-8')

# %%
df = pd.DataFrame(calls_df[0])

# %%
df.rename(columns={"بازگشایی؟": "open", "کمترین؟": 'low', 'بیشترین؟': 'high', 'پایانی؟': 'close'}, inplace=True)

# %%
df
# Out:
#         open       low      high     close  میزان تغییر درصد تغییر  \
# 0   10366000  10366000  10599000  10599000       229000      2.21%
# 1   10188000  10183000  10377000  10370000       187000      1.84%
# 2    9960000   9955000  10188000  10183000       228000      2.29%
# 3    9957000   9826000   9960000   9955000        88000      0.89%
# 4    9659000   9659000   9872000   9867000       203000       2.1%
# 5    9646000   9636000   9743000   9664000        14000      0.15%
# 6    9669000   9622000   9710000   9650000        14000      0.15%
# 7    9586000   9586000   9766000   9664000        74000      0.77%
# 8    9574000   9553000   9590000   9590000       205000      2.18%
# 9    9299000   9269000   9385000   9385000        93000         1%
# 10   9302000   9253000   9380000   9292000         5000      0.05%
# 11   9071000   9071000   9304000   9297000       222000      2.45%
# 12   8879000   8868000   9112000   9075000       184000      2.07%
# ...
