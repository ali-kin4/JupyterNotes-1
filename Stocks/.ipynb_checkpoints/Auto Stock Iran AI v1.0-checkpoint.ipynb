# %%
import os
import requests
import pandas as pd
import io
import urllib.request
import numpy as np
from datetime import timedelta
from sklearn.preprocessing import RobustScaler
import pylab as pp
# Technical Analysis library
import ta

# Neural Network library
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

pp.style.use("bmh")

# %%
os.chdir('D:/Stocks/')
file = 'Codes.csv'
codes = pd.read_csv(file)

# %%
code = str(codes.Codes[0])
url = "http://www.tsetmc.com/tsev2/data/Export-txt.aspx?t=i&a=1&b=0&i=" + code
r = requests.get(url, allow_redirects=True).content

# open('7769065543658313.csv', 'wb').write(r.content);

# %%
df = pd.read_csv(io.StringIO(r.decode('utf-8')))

# %%
## Datetime conversion
df['<DTYYYYMMDD>'] = pd.to_datetime(df['<DTYYYYMMDD>'], format='%Y%m%d')
df.rename(columns={"<DTYYYYMMDD>": "Date"}, inplace=True)
df['Date'] =pd.to_datetime(df.Date)
df = df.sort_values(by=['Date'])

# Setting the index
df.set_index('Date', inplace=True)

# Dropping any NaNs
df.dropna(inplace=True)

# %%
## Technical Indicators

# Adding all the indicators
df = ta.add_all_ta_features(df, open="<OPEN>", high="<HIGH>", low="<LOW>", close="<CLOSE>", volume="<VOL>", fillna=True)
# Out:
# c:\users\light\appdata\local\programs\python\python38\lib\site-packages\ta\trend.py:608: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# c:\users\light\appdata\local\programs\python\python38\lib\site-packages\ta\trend.py:612: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])

# %%
# Dropping everything else besides 'Close' and the Indicators
df.drop(['<TICKER>', '<FIRST>', '<HIGH>', '<LOW>', '<VALUE>', '<VOL>', '<OPENINT>', '<PER>', '<OPEN>', '<LAST>'], axis=1, inplace=True)

df.rename(columns={"<CLOSE>": "Close", "<DTYYYYMMDD>": "Date"}, inplace=True)

# Only using the last 1000 days of data to get a more accurate representation of the current market climate
df = df.tail(1500)

# %%
## Scaling

# Scale fitting the close prices separately for inverse_transformations purposes later
close_scaler = RobustScaler()

close_scaler.fit(df[['Close']])

# Normalizing/Scaling the DF
scaler = RobustScaler()

df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns, index=df.index)

# %%
def split_sequence(seq, n_steps_in, n_steps_out):
    """
    Splits the multivariate time sequence
    """
    
    # Creating a list for both variables
    X, y = [], []
    
    for i in range(len(seq)):
        
        # Finding the end of the current sequence
        end = i + n_steps_in
        out_end = end + n_steps_out
        
        # Breaking out of the loop if we have exceeded the dataset's length
        if out_end > len(seq):
            break
        
        # Splitting the sequences into: x = past prices and indicators, y = prices ahead
        seq_x, seq_y = seq[i:end, :], seq[end:out_end, 0]
        
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)


def visualize_training_results(results):
    """
    Plots the loss and accuracy for the training and testing data
    """
    history = results.history
    pp.figure(figsize=(16,5))
    pp.plot(history['val_loss'])
    pp.plot(history['loss'])
    pp.legend(['val_loss', 'loss'])
    pp.title('Loss')
    pp.xlabel('Epochs')
    pp.ylabel('Loss')
    pp.show()
    
    pp.figure(figsize=(16,5))
    pp.plot(history['val_accuracy'])
    pp.plot(history['accuracy'])
    pp.legend(['val_accuracy', 'accuracy'])
    pp.title('Accuracy')
    pp.xlabel('Epochs')
    pp.ylabel('Accuracy')
    pp.show()
    
    
def layer_maker(n_layers, n_nodes, activation, drop=None, d_rate=.5):
    """
    Creates a specified number of hidden layers for an RNN
    Optional: Adds regularization option - the dropout layer to prevent potential overfitting (if necessary)
    """
    
    # Creating the specified number of hidden layers with the specified number of nodes
    for x in range(1,n_layers+1):
        model.add(LSTM(n_nodes, activation=activation, return_sequences=True))

        # Adds a Dropout layer after every Nth hidden layer (the 'drop' variable)
        try:
            if x % drop == 0:
                model.add(Dropout(d_rate))
        except:
            pass
          

def validater(n_per_in, n_per_out):
    """
    Runs a 'For' loop to iterate through the length of the DF and create predicted values for every stated interval
    Returns a DF containing the predicted values for the model with the corresponding index values based on a business day frequency
    """
    
    # Creating an empty DF to store the predictions
    predictions = pd.DataFrame(index=df.index, columns=[df.columns[0]])

    for i in range(n_per_in, len(df)-n_per_in, n_per_out):
        # Creating rolling intervals to predict off of
        x = df[-i - n_per_in:-i]

        # Predicting using rolling intervals
        yhat = model.predict(np.array(x).reshape(1, n_per_in, n_features))

        # Transforming values back to their normal prices
        yhat = close_scaler.inverse_transform(yhat)[0]

        # DF to store the values and append later, frequency uses business days
        pred_df = pd.DataFrame(yhat, 
                               index=pd.date_range(start=x.index[-1], 
                                                   periods=len(yhat), 
                                                   freq="B"),
                               columns=[x.columns[0]])

        # Updating the predictions DF
        predictions.update(pred_df)
        
    return predictions


def val_rmse(df1, df2):
    """
    Calculates the root mean square error between the two Dataframes
    """
    df = df1.copy()
    
    # Adding a new column with the closing prices from the second DF
    df['close2'] = df2.Close
    
    # Dropping the NaN values
    df.dropna(inplace=True)
    
    # Adding another column containing the difference between the two DFs' closing prices
    df['diff'] = df.Close - df.close2
    
    # Squaring the difference and getting the mean
    rms = (df[['diff']]**2).mean()
    
    # Returning the sqaure root of the root mean square
    return float(np.sqrt(rms))

# %%
# How many periods looking back to learn
n_per_in  = 90
# How many periods to predict
n_per_out = 30
# Features 
n_features = df.shape[1]
# Splitting the data into appropriate sequences
X, y = split_sequence(df.to_numpy(), n_per_in, n_per_out)

# %%
## Creating the NN

# Instatiating the model
model = Sequential()

# Activation
activ = "tanh"

# Input layer
model.add(LSTM(90, 
               activation=activ, 
               return_sequences=True, 
               input_shape=(n_per_in, n_features)))

# Hidden layers
layer_maker(n_layers=1, 
            n_nodes=50, 
            activation=activ)

# Final Hidden layer
model.add(LSTM(60, activation=activ))

# Output layer
model.add(Dense(n_per_out))

# Model summary
model.summary()

# Compiling the data with selected specifications
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

## Fitting and Training
res = model.fit(X, y, epochs=50, batch_size=128, validation_split=0.1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 90, 90)            59040
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 90, 50)            28200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60)                26640
# _________________________________________________________________
# dense (Dense)                (None, 30)                1830
# =================================================================
# Total params: 115,710
# Trainable params: 115,710
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 10/10 [==============================] - 4s 428ms/step - loss: 0.1738 - accuracy: 0.0250 - val_loss: 1.1884 - val_accuracy: 0.0072
# Epoch 2/200
# 10/10 [==============================] - 3s 252ms/step - loss: 0.0628 - accuracy: 0.0274 - val_loss: 0.7838 - val_accuracy: 0.0072
# Epoch 3/200
# 10/10 [==============================] - 3s 266ms/step - loss: 0.0309 - accuracy: 0.0306 - val_loss: 0.6535 - val_accuracy: 0.0216
# Epoch 4/200
# 10/10 [==============================] - 2s 245ms/step - loss: 0.0178 - accuracy: 0.0233 - val_loss: 0.4973 - val_accuracy: 0.0216
# Epoch 5/200
# 10/10 [==============================] - 2s 249ms/step - loss: 0.0106 - accuracy: 0.0386 - val_loss: 0.4970 - val_accuracy: 0.0432
# Epoch 6/200
# 10/10 [==============================] - 3s 251ms/step - loss: 0.0077 - accuracy: 0.0435 - val_loss: 0.5026 - val_accuracy: 0.0144
# Epoch 7/200
# 10/10 [==============================] - 2s 244ms/step - loss: 0.0061 - accuracy: 0.0604 - val_loss: 0.4812 - val_accuracy: 0.0432
# Epoch 8/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0053 - accuracy: 0.0564 - val_loss: 0.5004 - val_accuracy: 0.0360
# Epoch 9/200
# 10/10 [==============================] - 2s 248ms/step - loss: 0.0047 - accuracy: 0.0749 - val_loss: 0.4961 - val_accuracy: 0.0576
# Epoch 10/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0042 - accuracy: 0.0878 - val_loss: 0.5169 - val_accuracy: 0.0360
# Epoch 11/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0038 - accuracy: 0.0853 - val_loss: 0.5236 - val_accuracy: 0.0432
# Epoch 12/200
# 10/10 [==============================] - 2s 236ms/step - loss: 0.0035 - accuracy: 0.0950 - val_loss: 0.5234 - val_accuracy: 0.0360
# Epoch 13/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0032 - accuracy: 0.0958 - val_loss: 0.5211 - val_accuracy: 0.0360
# Epoch 14/200
# 10/10 [==============================] - 2s 241ms/step - loss: 0.0030 - accuracy: 0.1095 - val_loss: 0.5304 - val_accuracy: 0.0288
# Epoch 15/200
# 10/10 [==============================] - 2s 244ms/step - loss: 0.0029 - accuracy: 0.1087 - val_loss: 0.5240 - val_accuracy: 0.0360
# Epoch 16/200
# 10/10 [==============================] - 2s 245ms/step - loss: 0.0027 - accuracy: 0.1208 - val_loss: 0.5316 - val_accuracy: 0.0432
# Epoch 17/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0026 - accuracy: 0.1208 - val_loss: 0.5328 - val_accuracy: 0.0216
# Epoch 18/200
# 10/10 [==============================] - 2s 236ms/step - loss: 0.0025 - accuracy: 0.1159 - val_loss: 0.5302 - val_accuracy: 0.0432
# Epoch 19/200
# 10/10 [==============================] - 2s 235ms/step - loss: 0.0024 - accuracy: 0.1361 - val_loss: 0.5358 - val_accuracy: 0.0360
# Epoch 20/200
# 10/10 [==============================] - 2s 235ms/step - loss: 0.0023 - accuracy: 0.1337 - val_loss: 0.5404 - val_accuracy: 0.0432
# Epoch 21/200
# 10/10 [==============================] - 2s 247ms/step - loss: 0.0023 - accuracy: 0.1304 - val_loss: 0.5256 - val_accuracy: 0.0360
# Epoch 22/200
# 10/10 [==============================] - 2s 240ms/step - loss: 0.0022 - accuracy: 0.1272 - val_loss: 0.5358 - val_accuracy: 0.0504
# Epoch 23/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0021 - accuracy: 0.1425 - val_loss: 0.5379 - val_accuracy: 0.0144
# Epoch 24/200
# 10/10 [==============================] - 2s 241ms/step - loss: 0.0020 - accuracy: 0.1353 - val_loss: 0.5323 - val_accuracy: 0.0504
# Epoch 25/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0020 - accuracy: 0.1393 - val_loss: 0.5283 - val_accuracy: 0.0288
# Epoch 26/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0019 - accuracy: 0.1377 - val_loss: 0.5225 - val_accuracy: 0.0576
# Epoch 27/200
# 10/10 [==============================] - 3s 265ms/step - loss: 0.0018 - accuracy: 0.1498 - val_loss: 0.5203 - val_accuracy: 0.0144
# Epoch 28/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0018 - accuracy: 0.1538 - val_loss: 0.5221 - val_accuracy: 0.0647
# Epoch 29/200
# 10/10 [==============================] - 2s 242ms/step - loss: 0.0017 - accuracy: 0.1361 - val_loss: 0.5250 - val_accuracy: 0.0432
# Epoch 30/200
# 10/10 [==============================] - 3s 259ms/step - loss: 0.0017 - accuracy: 0.1465 - val_loss: 0.5245 - val_accuracy: 0.0863
# Epoch 31/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0016 - accuracy: 0.1546 - val_loss: 0.5143 - val_accuracy: 0.0216
# Epoch 32/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0016 - accuracy: 0.1385 - val_loss: 0.5134 - val_accuracy: 0.0647
# Epoch 33/200
# 10/10 [==============================] - 3s 267ms/step - loss: 0.0015 - accuracy: 0.1481 - val_loss: 0.5351 - val_accuracy: 0.0935
# Epoch 34/200
# 10/10 [==============================] - 3s 280ms/step - loss: 0.0015 - accuracy: 0.1634 - val_loss: 0.5078 - val_accuracy: 0.0432
# Epoch 35/200
# 10/10 [==============================] - 3s 274ms/step - loss: 0.0015 - accuracy: 0.1651 - val_loss: 0.5058 - val_accuracy: 0.0288
# Epoch 36/200
# 10/10 [==============================] - 3s 272ms/step - loss: 0.0014 - accuracy: 0.1691 - val_loss: 0.4958 - val_accuracy: 0.0144
# Epoch 37/200
# 10/10 [==============================] - 3s 289ms/step - loss: 0.0014 - accuracy: 0.1554 - val_loss: 0.5154 - val_accuracy: 0.0288
# Epoch 38/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0013 - accuracy: 0.1844 - val_loss: 0.5206 - val_accuracy: 0.0504
# Epoch 39/200
# 10/10 [==============================] - 3s 269ms/step - loss: 0.0013 - accuracy: 0.1900 - val_loss: 0.5213 - val_accuracy: 0.0791
# Epoch 40/200
# 10/10 [==============================] - 3s 250ms/step - loss: 0.0012 - accuracy: 0.1876 - val_loss: 0.5179 - val_accuracy: 0.0072
# Epoch 41/200
# 10/10 [==============================] - 3s 266ms/step - loss: 0.0012 - accuracy: 0.1860 - val_loss: 0.5184 - val_accuracy: 0.0144
# Epoch 42/200
# 10/10 [==============================] - 3s 294ms/step - loss: 0.0012 - accuracy: 0.1948 - val_loss: 0.5251 - val_accuracy: 0.0288
# Epoch 43/200
# 10/10 [==============================] - 3s 268ms/step - loss: 0.0012 - accuracy: 0.1876 - val_loss: 0.5086 - val_accuracy: 0.0504
# Epoch 44/200
# 10/10 [==============================] - 3s 274ms/step - loss: 0.0012 - accuracy: 0.1884 - val_loss: 0.5150 - val_accuracy: 0.0504
# Epoch 45/200
# 10/10 [==============================] - 3s 278ms/step - loss: 0.0011 - accuracy: 0.1973 - val_loss: 0.5127 - val_accuracy: 0.0216
# Epoch 46/200
# 10/10 [==============================] - 3s 268ms/step - loss: 0.0011 - accuracy: 0.2005 - val_loss: 0.5191 - val_accuracy: 0.0288
# Epoch 47/200
# 10/10 [==============================] - 3s 256ms/step - loss: 0.0011 - accuracy: 0.1916 - val_loss: 0.5122 - val_accuracy: 0.0432
# Epoch 48/200
# 10/10 [==============================] - 2s 244ms/step - loss: 0.0011 - accuracy: 0.2053 - val_loss: 0.5189 - val_accuracy: 0.0791
# Epoch 49/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0011 - accuracy: 0.2182 - val_loss: 0.5313 - val_accuracy: 0.0072
# Epoch 50/200
# 10/10 [==============================] - 2s 243ms/step - loss: 0.0010 - accuracy: 0.1973 - val_loss: 0.5220 - val_accuracy: 0.0647
# Epoch 51/200
# 10/10 [==============================] - 2s 242ms/step - loss: 0.0010 - accuracy: 0.2198 - val_loss: 0.5259 - val_accuracy: 0.0719
# Epoch 52/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0010 - accuracy: 0.2045 - val_loss: 0.5302 - val_accuracy: 0.0647
# Epoch 53/200
# 10/10 [==============================] - 2s 241ms/step - loss: 0.0010 - accuracy: 0.2021 - val_loss: 0.5145 - val_accuracy: 0.0647
# Epoch 54/200
# 10/10 [==============================] - 2s 248ms/step - loss: 9.8807e-04 - accuracy: 0.2069 - val_loss: 0.5096 - val_accuracy: 0.0360
# Epoch 55/200
# 10/10 [==============================] - 2s 249ms/step - loss: 9.6464e-04 - accuracy: 0.2037 - val_loss: 0.5103 - val_accuracy: 0.0216
# Epoch 56/200
# 10/10 [==============================] - 2s 249ms/step - loss: 9.6218e-04 - accuracy: 0.2029 - val_loss: 0.5264 - val_accuracy: 0.0576
# Epoch 57/200
# 10/10 [==============================] - 3s 251ms/step - loss: 9.5064e-04 - accuracy: 0.2053 - val_loss: 0.5283 - val_accuracy: 0.0432
# Epoch 58/200
# 10/10 [==============================] - 3s 271ms/step - loss: 9.3623e-04 - accuracy: 0.2158 - val_loss: 0.5283 - val_accuracy: 0.0791
# Epoch 59/200
# 10/10 [==============================] - 3s 270ms/step - loss: 9.3203e-04 - accuracy: 0.2085 - val_loss: 0.5188 - val_accuracy: 0.0791
# Epoch 60/200
# 10/10 [==============================] - 3s 267ms/step - loss: 9.2761e-04 - accuracy: 0.2005 - val_loss: 0.5215 - val_accuracy: 0.0791
# Epoch 61/200
# 10/10 [==============================] - 3s 252ms/step - loss: 9.0769e-04 - accuracy: 0.2037 - val_loss: 0.5196 - val_accuracy: 0.0288
# Epoch 62/200
# 10/10 [==============================] - 2s 243ms/step - loss: 9.0135e-04 - accuracy: 0.2126 - val_loss: 0.5228 - val_accuracy: 0.0719
# Epoch 63/200
# 10/10 [==============================] - 2s 242ms/step - loss: 8.9453e-04 - accuracy: 0.2093 - val_loss: 0.5187 - val_accuracy: 0.0647
# Epoch 64/200
# 10/10 [==============================] - 2s 242ms/step - loss: 8.9884e-04 - accuracy: 0.2061 - val_loss: 0.5328 - val_accuracy: 0.0719
# Epoch 65/200
# 10/10 [==============================] - 3s 250ms/step - loss: 8.8513e-04 - accuracy: 0.2182 - val_loss: 0.5269 - val_accuracy: 0.0863
# Epoch 66/200
# 10/10 [==============================] - 3s 264ms/step - loss: 8.7281e-04 - accuracy: 0.2077 - val_loss: 0.5230 - val_accuracy: 0.0719
# Epoch 67/200
# 10/10 [==============================] - 3s 258ms/step - loss: 8.6313e-04 - accuracy: 0.2101 - val_loss: 0.5352 - val_accuracy: 0.0504
# Epoch 68/200
# 10/10 [==============================] - 3s 266ms/step - loss: 8.5138e-04 - accuracy: 0.2037 - val_loss: 0.5194 - val_accuracy: 0.0360
# Epoch 69/200
# 10/10 [==============================] - 3s 263ms/step - loss: 8.4111e-04 - accuracy: 0.2174 - val_loss: 0.5215 - val_accuracy: 0.0863
# Epoch 70/200
# 10/10 [==============================] - 3s 261ms/step - loss: 8.2430e-04 - accuracy: 0.2037 - val_loss: 0.5337 - val_accuracy: 0.0863
# Epoch 71/200
# 10/10 [==============================] - 2s 249ms/step - loss: 8.1431e-04 - accuracy: 0.2166 - val_loss: 0.5296 - val_accuracy: 0.0647
# Epoch 72/200
# 10/10 [==============================] - 2s 248ms/step - loss: 7.9818e-04 - accuracy: 0.2150 - val_loss: 0.5317 - val_accuracy: 0.0719
# Epoch 73/200
# 10/10 [==============================] - 2s 249ms/step - loss: 7.8351e-04 - accuracy: 0.2045 - val_loss: 0.5320 - val_accuracy: 0.0432
# Epoch 74/200
# 10/10 [==============================] - 2s 244ms/step - loss: 7.8378e-04 - accuracy: 0.2335 - val_loss: 0.5316 - val_accuracy: 0.0647
# Epoch 75/200
# 10/10 [==============================] - 3s 258ms/step - loss: 7.7341e-04 - accuracy: 0.2142 - val_loss: 0.5323 - val_accuracy: 0.0791
# Epoch 76/200
# 10/10 [==============================] - 2s 242ms/step - loss: 7.7975e-04 - accuracy: 0.2158 - val_loss: 0.5300 - val_accuracy: 0.0791
# Epoch 77/200
# 10/10 [==============================] - 2s 246ms/step - loss: 7.7307e-04 - accuracy: 0.2190 - val_loss: 0.5359 - val_accuracy: 0.0791
# Epoch 78/200
# 10/10 [==============================] - 2s 249ms/step - loss: 7.6589e-04 - accuracy: 0.2295 - val_loss: 0.5333 - val_accuracy: 0.0719
# Epoch 79/200
# 10/10 [==============================] - 2s 243ms/step - loss: 7.4418e-04 - accuracy: 0.2295 - val_loss: 0.5334 - val_accuracy: 0.0791
# Epoch 80/200
# 10/10 [==============================] - 2s 248ms/step - loss: 7.4146e-04 - accuracy: 0.2287 - val_loss: 0.5289 - val_accuracy: 0.0432
# Epoch 81/200
# 10/10 [==============================] - 3s 255ms/step - loss: 7.4290e-04 - accuracy: 0.2061 - val_loss: 0.5360 - val_accuracy: 0.0576
# Epoch 82/200
# 10/10 [==============================] - 2s 238ms/step - loss: 7.2877e-04 - accuracy: 0.2262 - val_loss: 0.5387 - val_accuracy: 0.0360
# Epoch 83/200
# 10/10 [==============================] - 3s 259ms/step - loss: 7.2336e-04 - accuracy: 0.2359 - val_loss: 0.5298 - val_accuracy: 0.0288
# Epoch 84/200
# 10/10 [==============================] - 3s 260ms/step - loss: 7.1317e-04 - accuracy: 0.2262 - val_loss: 0.5281 - val_accuracy: 0.0791
# Epoch 85/200
# 10/10 [==============================] - 3s 260ms/step - loss: 7.1553e-04 - accuracy: 0.2311 - val_loss: 0.5340 - val_accuracy: 0.0647
# Epoch 86/200
# 10/10 [==============================] - 3s 259ms/step - loss: 7.0659e-04 - accuracy: 0.2206 - val_loss: 0.5312 - val_accuracy: 0.0719
# Epoch 87/200
# 10/10 [==============================] - 3s 256ms/step - loss: 7.0653e-04 - accuracy: 0.2351 - val_loss: 0.5379 - val_accuracy: 0.0719
# Epoch 88/200
# 10/10 [==============================] - 3s 259ms/step - loss: 6.9515e-04 - accuracy: 0.2279 - val_loss: 0.5339 - val_accuracy: 0.0576
# Epoch 89/200
# 10/10 [==============================] - 3s 255ms/step - loss: 6.9314e-04 - accuracy: 0.2303 - val_loss: 0.5301 - val_accuracy: 0.0647
# Epoch 90/200
# 10/10 [==============================] - 3s 258ms/step - loss: 6.9264e-04 - accuracy: 0.2198 - val_loss: 0.5305 - val_accuracy: 0.0576
# Epoch 91/200
# 10/10 [==============================] - 3s 265ms/step - loss: 6.9229e-04 - accuracy: 0.2319 - val_loss: 0.5390 - val_accuracy: 0.0935
# Epoch 92/200
# 10/10 [==============================] - 3s 262ms/step - loss: 7.2030e-04 - accuracy: 0.2359 - val_loss: 0.5276 - val_accuracy: 0.0432
# Epoch 93/200
# 10/10 [==============================] - 3s 253ms/step - loss: 7.0068e-04 - accuracy: 0.2311 - val_loss: 0.5266 - val_accuracy: 0.0360
# Epoch 94/200
# 10/10 [==============================] - 3s 264ms/step - loss: 6.9344e-04 - accuracy: 0.2150 - val_loss: 0.5413 - val_accuracy: 0.0647
# Epoch 95/200
# 10/10 [==============================] - 3s 265ms/step - loss: 6.9202e-04 - accuracy: 0.2609 - val_loss: 0.5308 - val_accuracy: 0.0863
# Epoch 96/200
# 10/10 [==============================] - 3s 260ms/step - loss: 6.6347e-04 - accuracy: 0.2303 - val_loss: 0.5328 - val_accuracy: 0.0504
# Epoch 97/200
# 10/10 [==============================] - 3s 263ms/step - loss: 6.5452e-04 - accuracy: 0.2246 - val_loss: 0.5336 - val_accuracy: 0.0432
# Epoch 98/200
# 10/10 [==============================] - 3s 261ms/step - loss: 6.5532e-04 - accuracy: 0.2351 - val_loss: 0.5338 - val_accuracy: 0.0791
# Epoch 99/200
# 10/10 [==============================] - 3s 259ms/step - loss: 6.4767e-04 - accuracy: 0.2488 - val_loss: 0.5358 - val_accuracy: 0.0719
# Epoch 100/200
# 10/10 [==============================] - 3s 260ms/step - loss: 6.4423e-04 - accuracy: 0.2359 - val_loss: 0.5408 - val_accuracy: 0.0791
# Epoch 101/200
# 10/10 [==============================] - 3s 264ms/step - loss: 6.4734e-04 - accuracy: 0.2544 - val_loss: 0.5281 - val_accuracy: 0.0576
# Epoch 102/200
# 10/10 [==============================] - 3s 258ms/step - loss: 6.5051e-04 - accuracy: 0.2238 - val_loss: 0.5325 - val_accuracy: 0.0647
# Epoch 103/200
# 10/10 [==============================] - 2s 243ms/step - loss: 6.4196e-04 - accuracy: 0.2472 - val_loss: 0.5391 - val_accuracy: 0.0863
# Epoch 104/200
# 10/10 [==============================] - 2s 235ms/step - loss: 6.3558e-04 - accuracy: 0.2391 - val_loss: 0.5425 - val_accuracy: 0.0647
# Epoch 105/200
# 10/10 [==============================] - 2s 240ms/step - loss: 6.4414e-04 - accuracy: 0.2432 - val_loss: 0.5238 - val_accuracy: 0.0504
# Epoch 106/200
# 10/10 [==============================] - 2s 243ms/step - loss: 6.4729e-04 - accuracy: 0.2480 - val_loss: 0.5356 - val_accuracy: 0.0360
# Epoch 107/200
# 10/10 [==============================] - 2s 240ms/step - loss: 6.3823e-04 - accuracy: 0.2456 - val_loss: 0.5385 - val_accuracy: 0.0360
# Epoch 108/200
# 10/10 [==============================] - 2s 239ms/step - loss: 6.1662e-04 - accuracy: 0.2464 - val_loss: 0.5419 - val_accuracy: 0.0576
# Epoch 109/200
# 10/10 [==============================] - 2s 239ms/step - loss: 6.1243e-04 - accuracy: 0.2367 - val_loss: 0.5230 - val_accuracy: 0.0504
# Epoch 110/200
# 10/10 [==============================] - 2s 240ms/step - loss: 6.0933e-04 - accuracy: 0.2456 - val_loss: 0.5308 - val_accuracy: 0.0432
# Epoch 111/200
# 10/10 [==============================] - 2s 238ms/step - loss: 6.0081e-04 - accuracy: 0.2544 - val_loss: 0.5392 - val_accuracy: 0.0576
# Epoch 112/200
# 10/10 [==============================] - 2s 244ms/step - loss: 5.9907e-04 - accuracy: 0.2391 - val_loss: 0.5412 - val_accuracy: 0.0647
# Epoch 113/200
# 10/10 [==============================] - 2s 249ms/step - loss: 6.2245e-04 - accuracy: 0.2432 - val_loss: 0.5205 - val_accuracy: 0.0432
# Epoch 114/200
# 10/10 [==============================] - 3s 272ms/step - loss: 6.7618e-04 - accuracy: 0.2319 - val_loss: 0.5217 - val_accuracy: 0.0647
# Epoch 115/200
# 10/10 [==============================] - 3s 259ms/step - loss: 6.7741e-04 - accuracy: 0.2536 - val_loss: 0.5166 - val_accuracy: 0.0432
# Epoch 116/200
# 10/10 [==============================] - 2s 245ms/step - loss: 6.7369e-04 - accuracy: 0.2424 - val_loss: 0.5373 - val_accuracy: 0.0288
# Epoch 117/200
# 10/10 [==============================] - 2s 249ms/step - loss: 6.6368e-04 - accuracy: 0.2528 - val_loss: 0.5238 - val_accuracy: 0.0576
# Epoch 118/200
# 10/10 [==============================] - 3s 259ms/step - loss: 6.2323e-04 - accuracy: 0.2295 - val_loss: 0.5170 - val_accuracy: 0.0432
# Epoch 119/200
# 10/10 [==============================] - 2s 247ms/step - loss: 6.0667e-04 - accuracy: 0.2665 - val_loss: 0.5394 - val_accuracy: 0.0935
# Epoch 120/200
# 10/10 [==============================] - 2s 248ms/step - loss: 6.0039e-04 - accuracy: 0.2536 - val_loss: 0.5437 - val_accuracy: 0.0719
# Epoch 121/200
# 10/10 [==============================] - 3s 259ms/step - loss: 6.0108e-04 - accuracy: 0.2544 - val_loss: 0.5401 - val_accuracy: 0.0863
# Epoch 122/200
# 10/10 [==============================] - 3s 285ms/step - loss: 5.8539e-04 - accuracy: 0.2383 - val_loss: 0.5378 - val_accuracy: 0.0791
# Epoch 123/200
# 10/10 [==============================] - 2s 241ms/step - loss: 5.7678e-04 - accuracy: 0.2480 - val_loss: 0.5335 - val_accuracy: 0.0935
# Epoch 124/200
# 10/10 [==============================] - 2s 246ms/step - loss: 5.6648e-04 - accuracy: 0.2432 - val_loss: 0.5354 - val_accuracy: 0.1079
# Epoch 125/200
# 10/10 [==============================] - 2s 246ms/step - loss: 5.5979e-04 - accuracy: 0.2673 - val_loss: 0.5327 - val_accuracy: 0.1007
# Epoch 126/200
# 10/10 [==============================] - 2s 238ms/step - loss: 5.5521e-04 - accuracy: 0.2488 - val_loss: 0.5302 - val_accuracy: 0.0647
# Epoch 127/200
# 10/10 [==============================] - 2s 244ms/step - loss: 5.5122e-04 - accuracy: 0.2681 - val_loss: 0.5316 - val_accuracy: 0.0863
# Epoch 128/200
# 10/10 [==============================] - 3s 260ms/step - loss: 5.5441e-04 - accuracy: 0.2456 - val_loss: 0.5274 - val_accuracy: 0.0647
# Epoch 129/200
# 10/10 [==============================] - 3s 279ms/step - loss: 5.4060e-04 - accuracy: 0.2681 - val_loss: 0.5308 - val_accuracy: 0.0432
# Epoch 130/200
# 10/10 [==============================] - 3s 251ms/step - loss: 5.4555e-04 - accuracy: 0.2520 - val_loss: 0.5346 - val_accuracy: 0.0791
# Epoch 131/200
# 10/10 [==============================] - 2s 243ms/step - loss: 5.4255e-04 - accuracy: 0.2512 - val_loss: 0.5375 - val_accuracy: 0.1079
# Epoch 132/200
# 10/10 [==============================] - 2s 240ms/step - loss: 5.3653e-04 - accuracy: 0.2729 - val_loss: 0.5356 - val_accuracy: 0.0719
# Epoch 133/200
# 10/10 [==============================] - 2s 238ms/step - loss: 5.3364e-04 - accuracy: 0.2544 - val_loss: 0.5330 - val_accuracy: 0.1079
# Epoch 134/200
# 10/10 [==============================] - 2s 241ms/step - loss: 5.3449e-04 - accuracy: 0.2520 - val_loss: 0.5281 - val_accuracy: 0.1007
# Epoch 135/200
# 10/10 [==============================] - 2s 241ms/step - loss: 5.3333e-04 - accuracy: 0.2713 - val_loss: 0.5328 - val_accuracy: 0.1007
# Epoch 136/200
# 10/10 [==============================] - 2s 249ms/step - loss: 5.3772e-04 - accuracy: 0.2601 - val_loss: 0.5269 - val_accuracy: 0.0647
# Epoch 137/200
# 10/10 [==============================] - 3s 259ms/step - loss: 5.3385e-04 - accuracy: 0.2472 - val_loss: 0.5340 - val_accuracy: 0.1151
# Epoch 138/200
# 10/10 [==============================] - 3s 314ms/step - loss: 5.3654e-04 - accuracy: 0.2576 - val_loss: 0.5436 - val_accuracy: 0.0647
# Epoch 139/200
# 10/10 [==============================] - 3s 328ms/step - loss: 5.3872e-04 - accuracy: 0.2576 - val_loss: 0.5301 - val_accuracy: 0.0863
# Epoch 140/200
# 10/10 [==============================] - 3s 330ms/step - loss: 5.2876e-04 - accuracy: 0.2657 - val_loss: 0.5257 - val_accuracy: 0.0935
# Epoch 141/200
# 10/10 [==============================] - 3s 307ms/step - loss: 5.2517e-04 - accuracy: 0.2536 - val_loss: 0.5331 - val_accuracy: 0.1007
# Epoch 142/200
# 10/10 [==============================] - 3s 276ms/step - loss: 5.1339e-04 - accuracy: 0.2576 - val_loss: 0.5348 - val_accuracy: 0.1007
# Epoch 143/200
# 10/10 [==============================] - 3s 269ms/step - loss: 5.0910e-04 - accuracy: 0.2625 - val_loss: 0.5329 - val_accuracy: 0.0719
# Epoch 144/200
# 10/10 [==============================] - 3s 264ms/step - loss: 5.0067e-04 - accuracy: 0.2601 - val_loss: 0.5321 - val_accuracy: 0.0863
# Epoch 145/200
# 10/10 [==============================] - 3s 279ms/step - loss: 5.0965e-04 - accuracy: 0.2681 - val_loss: 0.5308 - val_accuracy: 0.0863
# Epoch 146/200
# 10/10 [==============================] - 3s 262ms/step - loss: 5.0308e-04 - accuracy: 0.2496 - val_loss: 0.5282 - val_accuracy: 0.0863
# Epoch 147/200
# 10/10 [==============================] - 3s 269ms/step - loss: 5.1500e-04 - accuracy: 0.2641 - val_loss: 0.5354 - val_accuracy: 0.1007
# Epoch 148/200
# 10/10 [==============================] - 3s 263ms/step - loss: 5.0869e-04 - accuracy: 0.2778 - val_loss: 0.5381 - val_accuracy: 0.0935
# Epoch 149/200
# 10/10 [==============================] - 3s 251ms/step - loss: 5.0048e-04 - accuracy: 0.2681 - val_loss: 0.5348 - val_accuracy: 0.0863
# Epoch 150/200
# 10/10 [==============================] - 3s 253ms/step - loss: 5.0044e-04 - accuracy: 0.2754 - val_loss: 0.5337 - val_accuracy: 0.0863
# Epoch 151/200
# 10/10 [==============================] - 3s 256ms/step - loss: 4.9761e-04 - accuracy: 0.2625 - val_loss: 0.5278 - val_accuracy: 0.0935
# Epoch 152/200
# 10/10 [==============================] - 2s 244ms/step - loss: 4.9778e-04 - accuracy: 0.2641 - val_loss: 0.5343 - val_accuracy: 0.1007
# Epoch 153/200
# 10/10 [==============================] - 2s 249ms/step - loss: 4.9770e-04 - accuracy: 0.2415 - val_loss: 0.5279 - val_accuracy: 0.0863
# Epoch 154/200
# 10/10 [==============================] - 3s 270ms/step - loss: 4.9410e-04 - accuracy: 0.2713 - val_loss: 0.5301 - val_accuracy: 0.1007
# Epoch 155/200
# 10/10 [==============================] - 3s 279ms/step - loss: 4.9070e-04 - accuracy: 0.2762 - val_loss: 0.5261 - val_accuracy: 0.1007
# Epoch 156/200
# 10/10 [==============================] - 3s 287ms/step - loss: 4.8543e-04 - accuracy: 0.2738 - val_loss: 0.5272 - val_accuracy: 0.0935
# Epoch 157/200
# 10/10 [==============================] - 2s 245ms/step - loss: 4.8206e-04 - accuracy: 0.2649 - val_loss: 0.5256 - val_accuracy: 0.1007
# Epoch 158/200
# 10/10 [==============================] - 3s 251ms/step - loss: 4.8632e-04 - accuracy: 0.2729 - val_loss: 0.5202 - val_accuracy: 0.1007
# Epoch 159/200
# 10/10 [==============================] - 2s 250ms/step - loss: 4.8334e-04 - accuracy: 0.2609 - val_loss: 0.5227 - val_accuracy: 0.0935
# Epoch 160/200
# 10/10 [==============================] - 3s 251ms/step - loss: 4.8896e-04 - accuracy: 0.2729 - val_loss: 0.5260 - val_accuracy: 0.0935
# Epoch 161/200
# 10/10 [==============================] - 3s 265ms/step - loss: 4.8643e-04 - accuracy: 0.2746 - val_loss: 0.5209 - val_accuracy: 0.0863
# Epoch 162/200
# 10/10 [==============================] - 2s 244ms/step - loss: 4.9665e-04 - accuracy: 0.2568 - val_loss: 0.5240 - val_accuracy: 0.1007
# Epoch 163/200
# 10/10 [==============================] - 2s 241ms/step - loss: 4.9027e-04 - accuracy: 0.2738 - val_loss: 0.5235 - val_accuracy: 0.1151
# Epoch 164/200
# 10/10 [==============================] - 3s 267ms/step - loss: 4.8906e-04 - accuracy: 0.2729 - val_loss: 0.5307 - val_accuracy: 0.1079
# Epoch 165/200
# 10/10 [==============================] - 3s 260ms/step - loss: 4.7711e-04 - accuracy: 0.2729 - val_loss: 0.5295 - val_accuracy: 0.1007
# Epoch 166/200
# 10/10 [==============================] - 2s 246ms/step - loss: 4.7504e-04 - accuracy: 0.2673 - val_loss: 0.5239 - val_accuracy: 0.1007
# Epoch 167/200
# 10/10 [==============================] - 2s 245ms/step - loss: 4.7440e-04 - accuracy: 0.2609 - val_loss: 0.5271 - val_accuracy: 0.0863
# Epoch 168/200
# 10/10 [==============================] - 2s 245ms/step - loss: 4.7465e-04 - accuracy: 0.2729 - val_loss: 0.5260 - val_accuracy: 0.1007
# Epoch 169/200
# 10/10 [==============================] - 2s 250ms/step - loss: 4.6927e-04 - accuracy: 0.2657 - val_loss: 0.5272 - val_accuracy: 0.0863
# Epoch 170/200
# 10/10 [==============================] - 2s 237ms/step - loss: 4.7776e-04 - accuracy: 0.2649 - val_loss: 0.5300 - val_accuracy: 0.1079
# Epoch 171/200
# 10/10 [==============================] - 3s 262ms/step - loss: 4.6883e-04 - accuracy: 0.2713 - val_loss: 0.5242 - val_accuracy: 0.0863
# Epoch 172/200
# 10/10 [==============================] - 2s 249ms/step - loss: 4.6533e-04 - accuracy: 0.2834 - val_loss: 0.5279 - val_accuracy: 0.1079
# Epoch 173/200
# 10/10 [==============================] - 2s 249ms/step - loss: 4.6498e-04 - accuracy: 0.2705 - val_loss: 0.5289 - val_accuracy: 0.1007
# Epoch 174/200
# 10/10 [==============================] - 3s 250ms/step - loss: 4.6227e-04 - accuracy: 0.2568 - val_loss: 0.5238 - val_accuracy: 0.1007
# Epoch 175/200
# 10/10 [==============================] - 2s 249ms/step - loss: 4.6295e-04 - accuracy: 0.2842 - val_loss: 0.5278 - val_accuracy: 0.1151
# Epoch 176/200
# 10/10 [==============================] - 3s 291ms/step - loss: 4.7006e-04 - accuracy: 0.2746 - val_loss: 0.5256 - val_accuracy: 0.1007
# Epoch 177/200
# 10/10 [==============================] - 2s 245ms/step - loss: 4.6608e-04 - accuracy: 0.2657 - val_loss: 0.5291 - val_accuracy: 0.1007
# Epoch 178/200
# 10/10 [==============================] - 3s 267ms/step - loss: 4.6565e-04 - accuracy: 0.2713 - val_loss: 0.5206 - val_accuracy: 0.0863
# Epoch 179/200
# 10/10 [==============================] - 3s 267ms/step - loss: 4.6381e-04 - accuracy: 0.2721 - val_loss: 0.5331 - val_accuracy: 0.1223
# Epoch 180/200
# 10/10 [==============================] - 3s 274ms/step - loss: 4.6396e-04 - accuracy: 0.2520 - val_loss: 0.5320 - val_accuracy: 0.0935
# Epoch 181/200
# 10/10 [==============================] - 3s 267ms/step - loss: 4.6018e-04 - accuracy: 0.2907 - val_loss: 0.5243 - val_accuracy: 0.1007
# Epoch 182/200
# 10/10 [==============================] - 3s 287ms/step - loss: 4.6607e-04 - accuracy: 0.2705 - val_loss: 0.5379 - val_accuracy: 0.1151
# Epoch 183/200
# 10/10 [==============================] - 3s 282ms/step - loss: 4.9320e-04 - accuracy: 0.2729 - val_loss: 0.5277 - val_accuracy: 0.1007
# Epoch 184/200
# 10/10 [==============================] - 3s 264ms/step - loss: 4.8531e-04 - accuracy: 0.2641 - val_loss: 0.5144 - val_accuracy: 0.0863
# Epoch 185/200
# 10/10 [==============================] - 3s 261ms/step - loss: 4.8219e-04 - accuracy: 0.2778 - val_loss: 0.5260 - val_accuracy: 0.0791
# Epoch 186/200
# 10/10 [==============================] - 3s 262ms/step - loss: 4.8971e-04 - accuracy: 0.2802 - val_loss: 0.5415 - val_accuracy: 0.1079
# Epoch 187/200
# 10/10 [==============================] - 3s 270ms/step - loss: 4.5958e-04 - accuracy: 0.2633 - val_loss: 0.5414 - val_accuracy: 0.1007
# Epoch 188/200
# 10/10 [==============================] - 3s 267ms/step - loss: 4.4694e-04 - accuracy: 0.2641 - val_loss: 0.5390 - val_accuracy: 0.1295
# Epoch 189/200
# 10/10 [==============================] - 3s 272ms/step - loss: 4.4311e-04 - accuracy: 0.2649 - val_loss: 0.5377 - val_accuracy: 0.1079
# Epoch 190/200
# 10/10 [==============================] - 3s 265ms/step - loss: 4.3776e-04 - accuracy: 0.2721 - val_loss: 0.5314 - val_accuracy: 0.0935
# Epoch 191/200
# 10/10 [==============================] - 3s 263ms/step - loss: 4.3245e-04 - accuracy: 0.2810 - val_loss: 0.5312 - val_accuracy: 0.0935
# Epoch 192/200
# 10/10 [==============================] - 3s 259ms/step - loss: 4.3573e-04 - accuracy: 0.2729 - val_loss: 0.5284 - val_accuracy: 0.0935
# Epoch 193/200
# 10/10 [==============================] - 3s 264ms/step - loss: 4.3272e-04 - accuracy: 0.2874 - val_loss: 0.5325 - val_accuracy: 0.0863
# Epoch 194/200
# 10/10 [==============================] - 3s 266ms/step - loss: 4.2986e-04 - accuracy: 0.2729 - val_loss: 0.5386 - val_accuracy: 0.0863
# Epoch 195/200
# 10/10 [==============================] - 3s 270ms/step - loss: 4.2368e-04 - accuracy: 0.2681 - val_loss: 0.5357 - val_accuracy: 0.1079
# Epoch 196/200
# 10/10 [==============================] - 3s 257ms/step - loss: 4.3067e-04 - accuracy: 0.2931 - val_loss: 0.5331 - val_accuracy: 0.0935
# Epoch 197/200
# 10/10 [==============================] - 3s 267ms/step - loss: 4.3197e-04 - accuracy: 0.2963 - val_loss: 0.5282 - val_accuracy: 0.1079
# Epoch 198/200
# 10/10 [==============================] - 3s 309ms/step - loss: 4.2925e-04 - accuracy: 0.2770 - val_loss: 0.5245 - val_accuracy: 0.0863
# Epoch 199/200
# 10/10 [==============================] - 3s 262ms/step - loss: 4.3234e-04 - accuracy: 0.2931 - val_loss: 0.5361 - val_accuracy: 0.1223
# Epoch 200/200
# 10/10 [==============================] - 3s 264ms/step - loss: 4.3335e-04 - accuracy: 0.2601 - val_loss: 0.5444 - val_accuracy: 0.1223

# %%
visualize_training_results(res)

# %%
# Transforming the actual values to their original price
actual = pd.DataFrame(close_scaler.inverse_transform(df[["Close"]]), 
                      index=df.index, 
                      columns=[df.columns[0]])

# Getting a DF of the predicted values to validate against
predictions = validater(n_per_in, n_per_out)

# Printing the RMSE
print("RMSE:", val_rmse(actual, predictions))
    
# Plotting
pp.figure(figsize=(16,6))

# Plotting those predictions
pp.plot(predictions, label='Predicted')

# Plotting the actual values
pp.plot(actual, label='Actual')

pp.title(f"Predicted vs Actual Closing Prices")
pp.ylabel("Price")
pp . legend ()
# pp . xlim ( '2015-05-01' , '2020-05-01' )
pp.show()
# Out:
# RMSE: 401.23541351554127

# %%
# Predicting off of the most recent days from the original DF
yhat = model.predict(np.array(df.tail(n_per_in)).reshape(1, n_per_in, n_features))

# Transforming the predicted values back to their original format
yhat = close_scaler.inverse_transform(yhat)[0]

# Creating a DF of the predicted prices
preds = pd.DataFrame(yhat, 
                     index=pd.date_range(start=df.index[-1]+timedelta(days=1), 
                                         periods=len(yhat), 
                                         freq="B"), 
                     columns=[df.columns[0]])

# Number of periods back to plot the actual values
pers = n_per_in

# Transforming the actual values to their original price
actual = pd.DataFrame(close_scaler.inverse_transform(df[["Close"]].tail(pers)), 
                      index=df.Close.tail(pers).index, 
                      columns=[df.columns[0]]).append(preds.head(1))

# Printing the predicted prices
print(preds)

# Plotting
pp.figure(figsize=(16,6))
pp.plot(actual, label="Actual Prices")
pp.plot(preds, label="Predicted Prices")
pp.ylabel("Price")
pp.xlabel("Dates")
pp.title(f"Forecasting the next {len(yhat)} days")
pp . legend ()
pp.show()
# Out:
#                   Close
# 2020-07-13  9271.111328
# 2020-07-14  9133.382812
# 2020-07-15  8832.448242
# 2020-07-16  9221.276367
# 2020-07-17  8521.413086
# 2020-07-20  8495.844727
# 2020-07-21  7929.468750
# 2020-07-22  7287.289062
# 2020-07-23  8019.003418
# 2020-07-24  8163.576172
# 2020-07-27  8974.231445
# 2020-07-28  8698.527344
# 2020-07-29  8429.027344
# 2020-07-30  8544.728516
# 2020-07-31  9032.962891
# 2020-08-03  8443.386719
# 2020-08-04  8364.535156
# 2020-08-05  8636.530273
# 2020-08-06  8504.640625
# 2020-08-07  8475.767578
# 2020-08-10  8253.687500
# 2020-08-11  7844.278320
# 2020-08-12  7955.856445
# 2020-08-13  8177.130371
# 2020-08-14  8160.575195
# 2020-08-17  8159.836426
# 2020-08-18  8343.340820
# 2020-08-19  7755.691406
# 2020-08-20  7722.809570
# 2020-08-21  8249.942383
