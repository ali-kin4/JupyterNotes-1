# %%
import os
import requests
import pandas as pd
import io
import urllib.request

os.chdir("D:\Stocks\PersianCal")
import PersianCal
import numpy as np

# %%
os.chdir('D:/Stocks/')
file = 'Codes.csv'
codes = pd.read_csv(file)
code = str(codes.Codes[code_number])

# %%
code_number = 100

code = str(codes.Codes[code_number])

# code = '45174198424472334'

url = "http://www.tsetmc.com/tsev2/data/Export-txt.aspx?t=i&a=1&b=0&i=" + code
r = requests.get(url, allow_redirects=True).content

# open('7769065543658313.csv', 'wb').write(r.content);

# %%
names = np.zeros((len(codes), 1)).tolist()
for i in range(len(codes)):
    code = str(codes.Codes[i])
    url = "http://www.tsetmc.com/tsev2/data/Export-txt.aspx?t=i&a=1&b=0&i=" + code
    r = requests.get(url, allow_redirects=True).content
    df = pd.read_csv(io.StringIO(r.decode('utf-8')))
    name = str(df['<TICKER>'][0]).replace('*', '')
    print("code = " + str(i) + ' | ' + 'Name: ' + name)
    names[i] = name
# Out:
# code = 0 | Name: Gol-E-Gohar.
# code = 1 | Name: SMobarakeh.Steel
# code = 2 | Name: Khalij.Fars
# code = 3 | Name: SI..N..C..Ind.
# code = 4 | Name: Social.Sec.Inv
# code = 5 | Name: SIsf..Oil.Ref.Co.
# code = 6 | Name: Tamin.Petro.
# code = 7 | Name: SMellat.Bank
# code = 8 | Name: STejarat.Bank
# code = 9 | Name: Saderat.Bank
# code = 10 | Name: B.A.Oil.Refinie
# code = 11 | Name: Iran.Kh..Inv.
# code = 12 | Name: Day.Bank
# code = 13 | Name: SIsfahan.Steel
# code = 14 | Name: Pars.Paper.Ind.Grp
# code = 15 | Name: Sabzevar.Cement
# code = 16 | Name: Cultur.Herit..Inv.
# code = 17 | Name: Iran.Office.Ind.
# code = 18 | Name: Kerman.Invest
# code = 19 | Name: Maroon.Petro.
# code = 20 | Name: Saba.Tamin.Inv.
# code = 21 | Name: Tondgooyan.Petro
# code = 22 | Name: Gohar.Zamin.Iron
# code = 23 | Name: SZagros.Petro.
# code = 24 | Name: Hormozgan.Co.
# code = 25 | Name: SKharazmy.Invest
# code = 26 | Name: Iran.Kh..A..M.
# code = 27 | Name: SIran.Chem..Ind.
# code = 28 | Name: Khavar.Spring
# code = 29 | Name: G.Barekat.Pharm
# code = 30 | Name: Iran.Refract.
# code = 31 | Name: SSabet.Khorasan
# code = 32 | Name: Pars.Darou
# code = 33 | Name: P..Animal.Feed
# code = 34 | Name: Kh..Pegah.Dairy
# code = 35 | Name: Hormozgan.Cem.
# code = 36 | Name: Isfahan.Cement
# code = 37 | Name: Sazeh.Pouyesh
# code = 38 | Name: Sepanta
# code = 39 | Name: Iranmerinos
# code = 40 | Name: Yazd.Jooshkab
# code = 41 | Name: Rouz.Darou.P.
# code = 42 | Name: R..Mill.Prod.
# code = 43 | Name: Iran.N..Inv.
# code = 44 | Name: Iran.Argham
# code = 45 | Name: DPI
# code = 46 | Name: Daroupakhash.I.
# code = 47 | Name: Kermanshah.Petr
# code = 48 | Name: Pension.Fund
# code = 49 | Name: Iran.Zinc.Mines
# code = 50 | Name: Saba.Noor
# code = 51 | Name: Ofogh.Koorosh-R
# code = 52 | Name: IRI.Marine.Co.-R
# code = 53 | Name: A..I..S..D.-R
# code = 54 | Name: Dr..Abidi.Lab.-R
# code = 55 | Name: Abouraihan.P.-R
# code = 56 | Name: Inv..Banking.-R
# code = 57 | Name: Iran.Refract.-R
# code = 58 | Name: Tamin.Cement
# code = 59 | Name: Parsian.leasing
# code = 60 | Name: Iran.Khodro
# code = 61 | Name: Palayesh.Tehran
# code = 62 | Name: Nahad.Mali.Energy
# code = 63 | Name: MAPNA
# code = 64 | Name: Damavand.Min.
# code = 65 | Name: SBehshahr.Inv.
# code = 66 | Name: Kowsar.Pharm.
# code = 67 | Name: Salemin.Factory
# code = 68 | Name: Fars.Chem..Ind.
# code = 69 | Name: SIran.Transfo
# code = 70 | Name: Marvdasht.Sugar
# code = 71 | Name: Lotos.Investment
# code = 72 | Name: Kalber.Dairy
# code = 73 | Name: Khorasan.Steel.Co.
# code = 74 | Name: Ghandi.Cables.
# code = 75 | Name: Ofogh.Koorosh
# code = 76 | Name: Commodity.Exch.
# code = 77 | Name: Good.Exch.Brk.
# code = 78 | Name: Good.Exch.Ins.
# code = 79 | Name: Good.Exch.Prd.
# code = 80 | Name: Ind..&.Mine.Inv
# code = 81 | Name: Chadormalu
# code = 82 | Name: Pars.Oil
# code = 83 | Name: Alborz.Darou
# code = 84 | Name: SIr.Inv.Petr.
# code = 85 | Name: Sobhan.Pharm
# code = 86 | Name: Dr..Abidi.Lab.
# code = 87 | Name: A..I..S..D.
# code = 88 | Name: Iran.Ind..Dev.
# code = 89 | Name: Pumpiran
# code = 90 | Name: Investment.Banking
# code = 91 | Name: Nirou.Moharreke
# code = 92 | Name: Razak.Lab.
# code = 93 | Name: SIRI.Marine.Co.
# code = 94 | Name: Abouraihan.P.
# code = 95 | Name: Ardekan.Ceramic
# code = 96 | Name: SEN.Bank
# code = 97 | Name: Shomal.Cement
# code = 98 | Name: Iran.Auto-Parts
# code = 99 | Name: Iran.Carton
# code = 100 | Name: Shahdiran.Inc.
# code = 101 | Name: Pars.Minoo
# code = 102 | Name: Tamin.Daroo
# code = 103 | Name: Iran.Darou
# code = 104 | Name: Kavir.Tire
# code = 105 | Name: Nirou.Inv.
# code = 106 | Name: I..Pegah.Dairy
# code = 107 | Name: Sepid.Farab.Kavir
# code = 108 | Name: Parsian.Bank
# code = 109 | Name: SSaipa
# code = 110 | Name: Dana.Insurance
# code = 111 | Name: Chin.Chin
# code = 112 | Name: Paksho
# code = 113 | Name: SMetals.&.Min.
# code = 114 | Name: Noush.Maz.
# code = 115 | Name: Tabriz.Oil.Refine
# code = 116 | Name: Glucosan
# code = 117 | Name: Sand.Foundry
# code = 118 | Name: Hafez.Tile
# code = 119 | Name: Ilam.Cement
# code = 120 | Name: Bafgh.Mining
# code = 121 | Name: Hegmatan.Sugar
# code = 122 | Name: Iran.Yasa.Tire
# code = 123 | Name: Iran.Fold
# code = 124 | Name: Gorji.Biscuit
# code = 125 | Name: Amin.Pharm.
# code = 126 | Name: Insurance.Inv.
# code = 127 | Name: GhaltakSaznSepahan
# code = 128 | Name: producing.CHDN
# code = 129 | Name: Iran.Casting
# code = 130 | Name: Iran.Board
# code = 131 | Name: Iran.Mineral.P.
# code = 132 | Name: Razi.P..Glasses
# code = 133 | Name: Iran.Tractor
# code = 134 | Name: Banks.Employees
# code = 135 | Name: Kaveh.Company
# code = 136 | Name: Tidewater
# code = 137 | Name: I..T..Foundry
# code = 138 | Name: Iran.China.Clay
# code = 139 | Name: Motorsazan
# code = 140 | Name: Fars.Dev.
# code = 141 | Name: Parsian
# code = 142 | Name: Iran.Amlah
# code = 143 | Name: STehranStockExch.
# code = 144 | Name: TSE.Brokers
# code = 145 | Name: TSE.financial
# code = 146 | Name: Pars.Switch
# code = 147 | Name: Khark.Petr.
# code = 148 | Name: Bank.of.M.E.
# code = 149 | Name: Sina.Darou.Lab.
# code = 150 | Name: Saipa.Azin
# code = 151 | Name: Spahan.Naft
# code = 152 | Name: Iran.Tractor.F.
# code = 153 | Name: Khoozestan.CE.
# code = 154 | Name: Farabi.Pharm.
# code = 155 | Name: SAlborz.Inv.
# code = 156 | Name: Mazandaran.Cem.
# code = 157 | Name: Etebari.Iran.Co
# code = 158 | Name: Azarbayjan.Inv.
# code = 159 | Name: Jaber.Hayan.P.
# code = 160 | Name: Iran.Mobil.Tele
# code = 161 | Name: SNovin.Investment
# code = 162 | Name: Soufian.Cement
# code = 163 | Name: Techinco
# code = 164 | Name: Behbahan.Cement
# code = 165 | Name: Khazar.Cement
# code = 166 | Name: Daroupakhsh.P.
# code = 167 | Name: Offset
# code = 168 | Name: Gharb.Cement.
# code = 169 | Name: Siman.Fars.Noe
# code = 170 | Name: Neiriz.Cement
# code = 171 | Name: Sarma.Afarin
# code = 172 | Name: Mahram.Mfg.
# code = 173 | Name: Saman-E-Kish
# code = 174 | Name: Zar.Spring
# code = 175 | Name: Khoy.Sugar.Co.
# code = 176 | Name: Hamkaran.System.Co
# code = 177 | Name: Technotar
# code = 178 | Name: Glass.and.Gas
# code = 179 | Name: Zahravi.Phar.
# code = 180 | Name: Khouz..Steel
# code = 181 | Name: Neyshabour.S.
# code = 182 | Name: Khalij.Fars.Trans
# code = 183 | Name: Abadan.Petr.
# code = 184 | Name: Toosgostar.Inv.
# code = 185 | Name: Paxan
# code = 186 | Name: Shahed.Inv.
# code = 187 | Name: Goltash
# code = 188 | Name: Mehrcam.Pars
# code = 189 | Name: Jaam.Darou
# code = 190 | Name: STehran.Const.
# code = 191 | Name: Lorestan.Sugar
# code = 192 | Name: Damloran.Pharm.
# code = 193 | Name: Pars.Tile
# code = 194 | Name: Doode.Sanati
# code = 195 | Name: Asan.Pardakht.Pers
# code = 196 | Name: Loghman.Pharm.
# code = 197 | Name: Jam.Petr.
# code = 198 | Name: Sobhan.Pharm.
# code = 199 | Name: Negin.Tabas.L.
# code = 200 | Name: Nasir.Machine
# code = 201 | Name: Iran.Parenteral
# code = 202 | Name: SNorth.Drilling
# code = 203 | Name: Inf..Services
# code = 204 | Name: Chimidarou
# code = 205 | Name: Behran.Oil
# code = 206 | Name: Rena.Investment
# code = 207 | Name: Behpardakht.Mellat
# code = 208 | Name: Qayen.Cement
# code = 209 | Name: W..Azar..Pegah
# code = 210 | Name: Parsian.Ecommerc
# code = 211 | Name: Bama
# code = 212 | Name: Osvah.Pharm.
# code = 213 | Name: Loabiran
# code = 214 | Name: E..Kh..Shargh
# code = 215 | Name: Ama
# code = 216 | Name: Kordesta.Ce..Co.
# code = 217 | Name: Sepah.Inv.
# code = 218 | Name: Behshahr.Group
# code = 219 | Name: NiroCholor
# code = 220 | Name: Irka.Part
# code = 221 | Name: Bahonar.Copper
# code = 222 | Name: Pardis.Invsetment
# code = 223 | Name: Azar.Refract.
# code = 224 | Name: Magsal.Agri.
# code = 225 | Name: Hamadan.Glass
# code = 226 | Name: SRayan.Saipa
# code = 227 | Name: Pars.Tousheh
# code = 228 | Name: Bime.Ma.Co.
# code = 229 | Name: Amirkabir.Steel
# code = 230 | Name: Sepahan.Cement
# code = 231 | Name: Cement.INV..Co.
# code = 232 | Name: Int..Const.
# code = 233 | Name: Behnoush.Iran
# code = 234 | Name: Pak.Dairy
# code = 235 | Name: Bahman.Group
# code = 236 | Name: Pars.Int..Mfg.
# code = 237 | Name: Ardebil.Cement
# code = 238 | Name: Nirou.Trans
# code = 239 | Name: Shazand.Petr.
# code = 240 | Name: Iran.Glass.Wool
# code = 241 | Name: Shahroud.Cement
# code = 242 | Name: Daroupakhsh
# code = 243 | Name: Oroumiyeh.Cem.
# code = 244 | Name: Kerman.Cement
# code = 245 | Name: SIran.Aluminium
# code = 246 | Name: Margarin
# code = 247 | Name: Alborz.Cable
# code = 248 | Name: Iran.Polyacryl
# code = 249 | Name: Fajr.E.Persia.Gulf
# code = 250 | Name: Kaveh.Paper
# code = 251 | Name: Saipa.Diesel
# code = 252 | Name: Dashtestan.Ce.
# code = 253 | Name: SPars.Khodro
# code = 254 | Name: Daroupakhsh
# code = 255 | Name: Iran.Motorcycle
# code = 256 | Name: Ghadir.Inv.
# code = 257 | Name: Ghazvin.Sugar
# code = 258 | Name: Atye.Damavand
# code = 259 | Name: Tukafoolad.Inv.
# code = 260 | Name: Kerman.Tire
# code = 261 | Name: Saipa.Glass
# code = 262 | Name: Shargh.Cement
# code = 263 | Name: SF..&.Kh..Cement
# code = 264 | Name: Niromohareke.M.
# code = 265 | Name: Ghadir.Kh..L.
# code = 266 | Name: Mellat.Insur.
# code = 267 | Name: Ansar.Bank
# code = 268 | Name: Plascokar.Saipa
# code = 269 | Name: Abadgaran
# code = 270 | Name: Tuka.Trans.
# code = 271 | Name: Housing.Inv.
# code = 272 | Name: Behshahr.Ind.
# code = 273 | Name: SSaipa.Inv.
# code = 274 | Name: Sina.Tile
# code = 275 | Name: Saadi.Tile
# code = 276 | Name: Exir.Pharm.
# code = 277 | Name: Iran.Tele..Co.
# code = 278 | Name: Mashad.Wheel
# code = 279 | Name: SArak.M..Mfg.
# code = 280 | Name: Charkheshgar
# code = 281 | Name: Zamyad
# code = 282 | Name: Bahman.Inv.
# code = 283 | Name: Oil.Ind..Inv.
# code = 284 | Name: Sahand.Rubber
# code = 285 | Name: Doroud.Cement
# code = 286 | Name: SParsian.Oil&Gas
# code = 287 | Name: SAlborz.Bimeh
# code = 288 | Name: Bank.Melli.Inv.
# code = 289 | Name: Iran.Radiator
# code = 290 | Name: Sepahan.Group
# code = 291 | Name: Buali.Inv.
# code = 292 | Name: SPasargad.Bank
# code = 293 | Name: Derakhshan.Teh.
# code = 294 | Name: Naghsh.Jahan.S.
# code = 295 | Name: Pardis.Petr.
# code = 296 | Name: Iran.Mn..Mines
# code = 297 | Name: Pars.Shahab
# code = 298 | Name: Darab.Cement
# code = 299 | Name: Maskan.Invest.
# code = 300 | Name: Piazar.Agro.
# code = 301 | Name: Iran.Yasa.Tire-R
# code = 302 | Name: Ind..&.M..L.
# code = 303 | Name: Absal
# code = 304 | Name: Aluminum.R.
# code = 305 | Name: Alomrad
# code = 306 | Name: Indamin
# code = 307 | Name: Tosee.Melli.Inv
# code = 308 | Name: Takceram
# code = 309 | Name: Sakht.Ajand
# code = 310 | Name: Pars.Ceram
# code = 311 | Name: Shiraz.Petr.
# code = 312 | Name: Sina.Chem..Ind.
# code = 313 | Name: Sina.Fin..Ins.
# code = 314 | Name: Omid.Inv..Mng.
# code = 315 | Name: Iran.Combine
# code = 316 | Name: Iran.Tire
# code = 317 | Name: Post.Bank
# code = 318 | Name: Farabi.Petr.
# code = 319 | Name: VAMCO
# code = 320 | Name: Iran.Khodro.D.
# code = 321 | Name: Calcimine
# code = 322 | Name: Iran.Ferr.
# code = 323 | Name: Shahroud.Sugar
# code = 324 | Name: Tehran.Cement
# code = 325 | Name: Karafarin.Bank
# code = 326 | Name: Motogen
# code = 327 | Name: Piranshahr.S.
# code = 328 | Name: Leasing.Iran
# code = 329 | Name: Alvand.Tile
# code = 330 | Name: SAzarab.Ind.
# code = 331 | Name: Isfahan.Sugar
# code = 332 | Name: Fars.Cement
# code = 333 | Name: Butane.Group
# code = 334 | Name: Iran.Brake.L.
# code = 335 | Name: Iran.Counter
# code = 336 | Name: Asia.Bime
# code = 337 | Name: Iran.M..&.P..M.
# code = 338 | Name: Lamiran
# code = 339 | Name: Pars.Pamchal
# code = 340 | Name: Petr..Tran.
# code = 341 | Name: Pars.Khazar
# code = 342 | Name: Kaavian.Steel
# code = 343 | Name: Nilou.Tile
# code = 344 | Name: Alumtek
# code = 345 | Name: N..I..L..Z.
# code = 346 | Name: Tehran.Darou
# code = 347 | Name: Tehran.Chemical
# code = 348 | Name: Iran.Tractor.M.
# code = 349 | Name: Tolypers
# code = 350 | Name: Khash.Cement
# code = 351 | Name: Keivan
# code = 352 | Name: Doroud.Farsit
# code = 353 | Name: Italran
# code = 354 | Name: Iran.Packing
# code = 355 | Name: Permit
# code = 356 | Name: Dasht.Morghab
# code = 357 | Name: PARS.Petrochemical
# code = 358 | Name: NORI.Petrochemical
# code = 359 | Name: Pars.Electric
# code = 360 | Name: Petro..Inv.
# code = 361 | Name: ShafaDarou.Inv.
# code = 362 | Name: Kowsar.Agri..Inv.
# code = 363 | Name: Boroujerd.T.
# code = 364 | Name: FKA.AGRI&Husb
# code = 365 | Name: Dashte.Khoramdareh
# code = 366 | Name: Day.Bime
# code = 367 | Name: Melli.Mortgage1902
# code = 368 | Name: Melli.Mortgage1903
# code = 369 | Name: Ghaed.Basir.Petro.
# code = 370 | Name: Melli.Mortgage1812
# code = 371 | Name: ParsianKosar.Hotel
# code = 372 | Name: Ghiam.AGRI&Husb
# code = 373 | Name: HejratDistribution
# code = 374 | Name: Talise.Company
# code = 375 | Name: Shahrood.N.E.
# code = 376 | Name: Melli.Mortgage1806
# code = 377 | Name: Melli.Mortgage1901
# code = 378 | Name: Bime.Saman.Co.
# code = 379 | Name: SBahman.Dizel.Co
# code = 380 | Name: Pegah.Golestan
# code = 381 | Name: A.S.P.CO
# code = 382 | Name: Tabarok.Ind..Group
# code = 383 | Name: Sina.Marine.srv
# code = 384 | Name: Parsian.Oil&Gas
# code = 385 | Name: Daroupakhsh.Distr.
# code = 386 | Name: Pakhsh.Alborz
# code = 387 | Name: Iran.Gel.Capsule
# code = 388 | Name: SGadir.Petro.
# code = 389 | Name: ReylSeir.IJR240302
# code = 390 | Name: SOV.MRB2-OMD210206
# code = 391 | Name: SSI-IJR2-AMN210316
# code = 392 | Name: IR.SharghMSH220115
# code = 393 | Name: EMobinIJRLOT230109
# code = 394 | Name: HekmatLESMSH220924
# code = 395 | Name: Arya.Sasol.Polymer
# code = 396 | Name: Pouya.Investment
# code = 397 | Name: Yazd.Tire
# code = 398 | Name: Melal.Credit.Inst.
# code = 399 | Name: Saveh.Cement
# code = 400 | Name: Ava.ETF
# code = 401 | Name: Ankolojy.Sobhan
# code = 402 | Name: TreasuryBill220803
# code = 403 | Name: Zagros.Meat.&.Milk
# code = 404 | Name: Iran.Fara.Bourse
# code = 405 | Name: General.Mechanic
# code = 406 | Name: Bargh.Mapna.Co.
# code = 407 | Name: Atrin.Nakh.Qom
# code = 408 | Name: SKhavarmiane.mine
# code = 409 | Name: Vitana
# code = 410 | Name: Zarin.Madan.Co.
# code = 411 | Name: Kimia.Zanjan.Co
# code = 412 | Name: Pegah.Golpayegan
# code = 413 | Name: Pegah.Fars.Co.
# code = 414 | Name: Amin.Company
# code = 415 | Name: Shomal.Gharb.Co
# code = 416 | Name: Isfahan.Kesht.Agr.
# code = 417 | Name: Minoo.Co.
# code = 418 | Name: Reyl.Pardazseir
# code = 419 | Name: SMesSarcheshme
# code = 420 | Name: Toucaril.Co.
# code = 421 | Name: Kosar.Ins.
# code = 422 | Name: Omid.Goharan
# code = 423 | Name: Atieh.Dade.Pardaz
# code = 424 | Name: Tuka.Paint.Co.
# code = 425 | Name: SArfa.Steel.Co.
# code = 426 | Name: Ava.Novin.INVEST
# code = 427 | Name: SIranian.Etekai
# code = 428 | Name: Tabas.Company
# code = 429 | Name: SPasargad.Insur.
# code = 430 | Name: Kaspian.Daroo
# code = 431 | Name: Alborz.Bulk.Co.
# code = 432 | Name: Mobin.One.Kish
# code = 433 | Name: Tolid.Daroo
# code = 434 | Name: Alborz.Invest.
# code = 435 | Name: Marjan.Kar
# code = 436 | Name: Iran.&.Shargh.Lsg.
# code = 437 | Name: Behpak.Co.
# code = 438 | Name: Rail.Sair.Kosar
# code = 439 | Name: Shahdab.Khorasan
# code = 440 | Name: Avicenna.Labs.
# code = 441 | Name: Afra..Net.Co.
# code = 442 | Name: KBC.Company
# code = 443 | Name: Rishmac.Prod.&EXP
# code = 444 | Name: Alvand.Housing.Inv
# code = 445 | Name: Mortgage.Right9701
# code = 446 | Name: Mortgage.Right9612
# code = 447 | Name: Mihan.Insurance
# code = 448 | Name: Mortgage.Right9611
# code = 449 | Name: Tadbirgaran.Inv
# code = 450 | Name: Const.and.Rail
# code = 451 | Name: Maskan.Pardis
# code = 452 | Name: Mortgage.Right9610
# code = 453 | Name: Mortgage.Right9609
# code = 454 | Name: Mortgage.Right9608
# code = 455 | Name: Mortgage.Right9607
# code = 456 | Name: Mortgage.Right9606
# code = 457 | Name: Baghmishe
# code = 458 | Name: Mortgage.Right9605
# code = 459 | Name: Mortgage.Right9604
# code = 460 | Name: Iranol
# code = 461 | Name: NPSZ
# code = 462 | Name: Hekmat.Iranian
# code = 463 | Name: Mortgage.Right9603
# code = 464 | Name: Omid.Taban.Hoor
# code = 465 | Name: TUKA.Co.
# code = 466 | Name: Mortgage.Right9602
# code = 467 | Name: Mortgage.Right9601
# code = 468 | Name: Mortgage.Right9512
# code = 469 | Name: Ghand.Shirvan
# code = 470 | Name: Mortgage.Right9511
# code = 471 | Name: Mortgage.Right9510
# code = 472 | Name: Mortgage.Right9509
# code = 473 | Name: Ravan.Fan.Avar
# code = 474 | Name: BANK.MASKAN
# code = 475 | Name: BANK.MASKAN
# code = 476 | Name: Kahnooj.Mahtab.Pow
# code = 477 | Name: BANK.MASKAN
# code = 478 | Name: Hamkaran.System
# code = 479 | Name: BANK.MASKAN
# code = 480 | Name: Damavand.Co.
# code = 481 | Name: BANK.MASKAN
# code = 482 | Name: BANK.MASKAN
# code = 483 | Name: Palayesh.Tehran
# code = 484 | Name: Khazar.Shipping
# code = 485 | Name: BANK.MASKAN
# code = 486 | Name: Maskan.Invest.
# code = 487 | Name: BANK.MASKAN
# code = 488 | Name: Yazd.Fold
# code = 489 | Name: BANK.MASKAN
# code = 490 | Name: Pars.Paper.Ind.Grp
# code = 491 | Name: BANK.MASKAN
# code = 492 | Name: Bahman.Liz.
# code = 493 | Name: BANK.MASKAN
# code = 494 | Name: BANK.MASKAN
# code = 495 | Name: Shahed.Development
# code = 496 | Name: Sobhan.Pharm
# code = 497 | Name: BANK.MASKAN
# code = 498 | Name: Sobhan.Invest.
# code = 499 | Name: BANK.MASKAN
# code = 500 | Name: Ghassem.Co.
# code = 501 | Name: BANK.MASKAN
# code = 502 | Name: Zayandeh.Maskan
# code = 503 | Name: BANK.MASKAN
# code = 504 | Name: BANK.MASKAN
# code = 505 | Name: BANK.MASKAN
# code = 506 | Name: BANK.MASKAN
# code = 507 | Name: BANK.MASKAN
# code = 508 | Name: BANK.MASKAN
# code = 509 | Name: BANK.MASKAN
# code = 510 | Name: BANK.MASKAN
# code = 511 | Name: BANK.MASKAN
# code = 512 | Name: BANK.MASKAN
# code = 513 | Name: BANK.MASKAN
# code = 514 | Name: Tourism.Bank
# code = 515 | Name: Jam.Petrochemical
# code = 516 | Name: BANK.MASKAN
# code = 517 | Name: BANK.MASKAN
# code = 518 | Name: BANK.MASKAN
# code = 519 | Name: BANK.MASKAN
# code = 520 | Name: BANK.MASKAN
# code = 521 | Name: BANK.MASKAN
# code = 522 | Name: BANK.MASKAN
# code = 523 | Name: BANK.MASKAN
# code = 524 | Name: BANK.MASKAN
# code = 525 | Name: Zangan.Industry
# code = 526 | Name: BANK.MASKAN
# code = 527 | Name: BANK.MASKAN
# code = 528 | Name: BANK.MASKAN
# code = 529 | Name: BANK.MASKAN
# code = 530 | Name: BANK.MASKAN
# code = 531 | Name: Saba.Noor
# code = 532 | Name: Bank.Maskan
# code = 533 | Name: Maskan.Invest.
# code = 534 | Name: Bank.Maskan
# code = 535 | Name: Bank.Maskan
# code = 536 | Name: Bank.Maskan
# code = 537 | Name: Bank.Maskan
# code = 538 | Name: Bank.Maskan
# code = 539 | Name: Bank.Maskan
# code = 540 | Name: Bank.Maskan
# code = 541 | Name: Bank.Maskan
# code = 542 | Name: Bank.Maskan
# code = 543 | Name: Kharazmy.Invest
# code = 544 | Name: Bank.Maskan
# code = 545 | Name: Bank.Maskan
# code = 546 | Name: MiddleEast.BanK
# code = 547 | Name: Bank.Maskan
# code = 548 | Name: Bank.Maskan
# code = 549 | Name: Bank.Maskan
# code = 550 | Name: Bank.Maskan
# code = 551 | Name: Bank.Maskan
# code = 552 | Name: Petro.Gachsaran
# code = 553 | Name: Anformatic.IR
# code = 554 | Name: Banks.Employees
# code = 555 | Name: Bank.Maskan
# code = 556 | Name: Bank.Maskan
# code = 557 | Name: Bank.Maskan
# code = 558 | Name: Morvarid.Petr.
# code = 559 | Name: Rikhtegari.Co.
# code = 560 | Name: Tourism.Dev..Co
# code = 561 | Name: Bank.Maskan
# code = 562 | Name: Bank.Maskan
# code = 563 | Name: Bank.Maskan
# code = 564 | Name: Bank.Maskan
# code = 565 | Name: Iran.Zamin.Bank
# code = 566 | Name: Bank.Maskan
# code = 567 | Name: Investment.Bank
# code = 568 | Name: Bank.Maskan
# code = 569 | Name: Arian.e-Bank
# code = 570 | Name: Bank.Maskan
# code = 571 | Name: Pardis.Petr
# code = 572 | Name: Bank.Maskan
# code = 573 | Name: Bank.Maskan
# code = 574 | Name: Bank.Maskan
# code = 575 | Name: Iran.Mobile.Tele
# code = 576 | Name: Bank.Maskan
# code = 577 | Name: Bank.Maskan
# code = 578 | Name: SKhavarmiane.mine
# code = 579 | Name: Jahrom.Power.Plant
# code = 580 | Name: SHepco
# code = 581 | Name: SADRA
# code = 582 | Name: Lordegan.Petr.
# code = 583 | Name: SKerman.Khodro.E.
# code = 584 | Name: Azadegan.Co.
# code = 585 | Name: SSaman.Bank
# code = 586 | Name: SIranKhodroDiesel
# code = 587 | Name: Padideh.Shandiz
# code = 588 | Name: SAyandeh.Bank
# code = 589 | Name: SCity.Bank
# code = 590 | Name: Iran.Zamin.Bank
# code = 591 | Name: Ahwaz.Rolling.Co
# code = 592 | Name: Folad.Kavian
# code = 593 | Name: Payam.Ind.
# code = 594 | Name: Gazlouleh
# code = 595 | Name: SadidPipe-Bankrupt
# code = 596 | Name: Abgineh
# code = 597 | Name: Permit
# code = 598 | Name: Madacto.Steel.Cord
# code = 599 | Name: PetroSanat.Gameron
# code = 600 | Name: Gaz.Sekkeh
# code = 601 | Name: Anti.Covid-19.CF2
# code = 602 | Name: Moallem.Insurance
# code = 603 | Name: MiddleEast.LifeINS
# code = 604 | Name: Kowsar.F.&C.
# code = 605 | Name: Lia.company
# code = 606 | Name: Adak.Ind..&.BSNS
# code = 607 | Name: Torbate.Jaam.S.
# code = 608 | Name: Sadid.Group
# code = 609 | Name: SPolyacryl.Iran
# code = 610 | Name: Etebari.Dev.Co
# code = 611 | Name: Dehdasht.Petro.
# code = 612 | Name: Kazeroon.Petro.
# code = 613 | Name: Mamasani.Petro.
# code = 614 | Name: Man-madeFibres.MFR
# code = 615 | Name: Golestan.Petro.
# code = 616 | Name: Iran.Cable
# code = 617 | Name: Behesht.Pars.Co

# %%
name_data = {'Name': names,
             'Codes': codes.Codes.tolist()}
name_dataF = pd.DataFrame(name_data)
name_dataF.set_index('Name', inplace=True)
name_dataF.to_csv("Code Name Data.csv")

# %%
df = pd.read_csv(io.StringIO(r.decode('utf-8')))

# %%
## Datetime conversion
df['<DTYYYYMMDD>'] = pd.to_datetime(df['<DTYYYYMMDD>'], format='%Y%m%d')

# Dropping any NaNs
df.dropna(inplace=True)

df.rename(columns={"<DTYYYYMMDD>": "Date"}, inplace=True)

# %%
df['Date'] =pd.to_datetime(df.Date)
df = df.sort_values(by=['Date'])

# %%
d = []
for i in range(len(df["Date"])):
    d.append(PersianCal.Gregorian(str(df["Date"][i])[0:10]).persian_string()) #Tabdil tarikh be Irani

# %%
for i in range(len(df["Date"])):
    df["Date"] = df["Date"].replace(df["Date"][i], d[i])

# %%
date_list = []
for date in df["Date"]:
    date_list.append(date[:7])
    
Dates = df["Date"].tolist() #kole tarikh ha
myDates = list(dict.fromkeys(date_list)) #Eshterake Tatikh ha

# %%
ext = np.zeros((len(myDates), 2)) #[[max], [min]]
ind = np.zeros((len(myDates), 1)).tolist()

#first indicator
for date in Dates:
    if (date[:7] in myDates[0]):
        ind1 = Dates.index(date) #یافتن مکان آخرین روز ماه

ind[0] = ind1

a = [[], [], [], []]
names = ["<FIRST>", "<HIGH>", "<LOW>", "<CLOSE>"]
for i in range(4):
    for j in names:
        a[i] = df[j][0:ind1].tolist()
        
ext[0][0] = max(max(a))
ext[0][1] = min(min(a))

# %%
for i in range(1, len(myDates)):
    for date in Dates:
        if (date[:7] in myDates[i]):
            ind1 = Dates.index(date)
    ind[i] = ind1
    a = [[], [], [], []]
    for ii in range(4):
        for j in names:
            a[ii] = df[j][ind[i-1]:ind[i]].tolist()
    ext[i][0] = max(max(a))
    ext[i][1] = min(min(a))

# %%
Data = {"Date": myDates,
        "Max": ext[:, 0],
        "Min": ext[:, 1]}
DataF = pd.DataFrame(Data)

DataF.set_index('Date', inplace=True)

# %%
os.chdir("D:/")

file_name = str(df['<TICKER>'][1]).replace('*', '')

DataF.to_csv(file_name + '.csv')

# %%
# import pylab as pp
# %matplotlib notebook
# pp.plot(DataF["Date"], DataF["Max"], color='skyblue', label = "Max")
# pp.plot(DataF["Date"], DataF["Min"], color='red', label = "Min")
# pp.legend();
